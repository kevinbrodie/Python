# %%
import gym
from sklearn.ensemble import RandomForestRegressor
import pandas as pd
import numpy as np
import random

#
# solved using fitted q-iteration over randomforest
#

clf = None
env = gym.make('CartPole-v0')

def get_point(pre, action, reward, post):
  """ returns a tuple (state, action, reward, post-state) """
  return np.array([pre.tolist() + [action] + [reward] + post.tolist()])

def get_action(clf, p_feat, exploration, space):
  """ given the q-function estimage (clf), the state p_feat, an exploration noise threshold, and an action space, returns action """
  feat = np.append(p_feat, 0)
  a = clf.predict(feat.reshape(1, -1))[0]
  feat = np.append(p_feat, 1)
  b = clf.predict(feat.reshape(1, -1))[0]
  # print("%s %s" % (a,b))
  if random.random() < exploration:
    action = space.sample()
  elif a > b:
    action = 0
  elif b > a:
    action = 1
  else:
    action = space.sample()
  # print("action chosen %s" % action)
  return action


def get_tree(obs, nb_it):
  #
  # fitted q-iteration
  # ref: Tree-Based Batch Mode Reinforcement Learning, Ernst, Guerst
  # 
  reg = None
  d_rate = 0.95
  df = pd.DataFrame(obs, columns=['a', 'b', 'c', 'd', 'action', 'reward', 'x', 'y', 'z', 'w'])
  for n in range(nb_it):
      # training an estimate of q_1
    if reg is not None:
      # using previous classifier as estimate of q_n-1
      features = df.columns[6:10]
      df2 = df[features]
      length = df2.shape[0]
      res = reg.predict(pd.concat([df2, pd.DataFrame(np.zeros(length))], axis=1))
      res2 = reg.predict(pd.concat([df2, pd.DataFrame(np.ones(length))], axis=1))
      # preparing our new training data set
      # if reward is 0, don't allow expected future reward to be positive
      df['max_reward'] = df['reward'] + (df['reward'] == 1)*(np.amax([res, res2], axis=0) * d_rate)
      # print("obs len: %s - nb iteration: %s - max reward: %s" % (len(obs), nb_it, np.max(df['max_reward'])))
    else:
      df['max_reward'] = df['reward']
    features = df.columns[:5]
    reg = RandomForestRegressor()
    reg = reg.fit(df[features], df['max_reward'])
    score = reg.score(df[features], df['max_reward'])
  # print("training - score is %s" % (score))
  return reg


#
# getting initial trajectories
#
tmp = None
post_observation = None
k = 0
for e in range(2000):
  pre_observation = env.reset()
  exploration = max(1.0/2**(e/2), 0)
  print("exploration = %s" % exploration)
  for t in range(1000):
    env.render()
    if post_observation is not None:
      pre_observation = post_observation
    if clf is None:
      action = env.action_space.sample()
    else:
      action = get_action(clf, pre_observation, exploration, env.action_space)
      # print(pre_observation)
    post_observation, reward, done, info = env.step(action)
    if done:
      print("Episode %s finished after timestamp %s" % (e, t))
      if t < 199:
          # simple reward shaping
          reward = -50
      tmp2 = get_point(pre_observation, action, reward, post_observation)
      tmp = np.append(tmp, tmp2, 0)
      break
    if tmp is None:
      tmp = get_point(pre_observation, action, reward, post_observation)
    else:
      tmp2 = get_point(pre_observation, action, reward, post_observation)
      tmp = np.append(tmp, tmp2, 0)
  if t < 199:
    clf = get_tree(tmp, max(e + 10, 30))
    k = 0
  else:
    k = k + 1
  print("nb hits %s" % k)
  if k > 100:
    break
# Out:
# [2016-11-15 21:50:23,207] Making new env: CartPole-v0
# exploration = 1.0
# Episode 0 finished after timestamp 12
# nb hits 0
# exploration = 0.7071067811865475
# Episode 1 finished after timestamp 10
# nb hits 0
# exploration = 0.5
# Episode 2 finished after timestamp 27
# nb hits 0
# exploration = 0.35355339059327373
# Episode 3 finished after timestamp 13
# nb hits 0
# exploration = 0.25
# Episode 4 finished after timestamp 46
# nb hits 0
# exploration = 0.17677669529663687
# Episode 5 finished after timestamp 26
# nb hits 0
# exploration = 0.125
# Episode 6 finished after timestamp 18
# nb hits 0
# exploration = 0.08838834764831843
# Episode 7 finished after timestamp 96
# nb hits 0
# exploration = 0.0625
# Episode 8 finished after timestamp 110
# nb hits 0
# exploration = 0.044194173824159216
# Episode 9 finished after timestamp 109
# nb hits 0
# exploration = 0.03125
# Episode 10 finished after timestamp 68
# nb hits 0
# exploration = 0.022097086912079608
# Episode 11 finished after timestamp 352
# nb hits 1
# exploration = 0.015625
# Episode 12 finished after timestamp 218
# nb hits 2
# exploration = 0.011048543456039804
# Episode 13 finished after timestamp 288
# nb hits 3
# exploration = 0.0078125
# Episode 14 finished after timestamp 293
# nb hits 4
# exploration = 0.005524271728019902
# Episode 15 finished after timestamp 297
# nb hits 5
# exploration = 0.00390625
# Episode 16 finished after timestamp 305
# nb hits 6
# exploration = 0.002762135864009951
# Episode 17 finished after timestamp 294
# nb hits 7
# exploration = 0.001953125
# Episode 18 finished after timestamp 276
# nb hits 8
# exploration = 0.0013810679320049755
# Episode 19 finished after timestamp 283
# nb hits 9
# exploration = 0.0009765625
# Episode 20 finished after timestamp 85
# nb hits 0
# exploration = 0.0006905339660024878
# Episode 21 finished after timestamp 390
# nb hits 1
# exploration = 0.00048828125
# Episode 22 finished after timestamp 202
# nb hits 2
# exploration = 0.0003452669830012439
# Episode 23 finished after timestamp 591
# nb hits 3
# exploration = 0.000244140625
# Episode 24 finished after timestamp 560
# nb hits 4
# exploration = 0.00017263349150062194
# Episode 25 finished after timestamp 371
# nb hits 5
# exploration = 0.0001220703125
# Episode 26 finished after timestamp 814
# nb hits 6
# exploration = 8.631674575031097e-05
# Episode 27 finished after timestamp 341
# nb hits 7
# exploration = 6.103515625e-05
# Episode 28 finished after timestamp 598
# nb hits 8
# exploration = 4.3158372875155485e-05
# Episode 29 finished after timestamp 618
# nb hits 9
# exploration = 3.0517578125e-05
# Episode 30 finished after timestamp 264
# nb hits 10
# exploration = 2.1579186437577742e-05
# Episode 31 finished after timestamp 378
# nb hits 11
# exploration = 1.52587890625e-05
# Episode 32 finished after timestamp 687
# nb hits 12
# exploration = 1.0789593218788871e-05
# Episode 33 finished after timestamp 338
# nb hits 13
# exploration = 7.62939453125e-06
# Episode 34 finished after timestamp 323
# nb hits 14
# exploration = 5.394796609394436e-06
# Episode 35 finished after timestamp 323
# nb hits 15
# exploration = 3.814697265625e-06
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-d5a475a479fb> in <module>()
#      77   print("exploration = %s" % exploration)
#      78   for t in range(1000):
# ---> 79     env.render()
#      80     if post_observation is not None:
#      81       pre_observation = post_observation
#
# c:\users\kbrodie\gym\gym\core.py in render(self, mode, close)
#     190             raise error.UnsupportedMode('Unsupported rendering mode: {}. (Supported modes for {}: {})'.format(mode, self, modes))
#     191
# --> 192         return self._render(mode=mode, close=close)
#     193
#     194     def close(self):
#
# c:\users\kbrodie\gym\gym\envs\classic_control\cartpole.py in _render(self, mode, close)
#     147         self.poletrans.set_rotation(-x[2])
#     148
# --> 149         return self.viewer.render(return_rgb_array = mode=='rgb_array')
#
# c:\users\kbrodie\gym\gym\envs\classic_control\rendering.py in render(self, return_rgb_array)
#      81         glClearColor(1,1,1,1)
#      82         self.window.clear()
# ---> 83         self.window.switch_to()
#      84         self.window.dispatch_events()
#      85         self.transform.enable()
#
# C:\Users\KBrodie\AppData\Local\Continuum\Anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in switch_to(self)
#     305
#     306     def switch_to(self):
# --> 307         self.context.set_current()
#     308
#     309     def flip(self):
#
# C:\Users\KBrodie\AppData\Local\Continuum\Anaconda3\lib\site-packages\pyglet\gl\win32.py in set_current(self)
#     212     def set_current(self):
#     213         if self._context is not None:
# --> 214             wgl.wglMakeCurrent(self.canvas.hdc, self._context)
#     215         super(Win32Context, self).set_current()
#     216
#
# KeyboardInterrupt:
